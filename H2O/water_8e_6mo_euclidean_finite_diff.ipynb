# %%
################ Code from the 'Optimization of molecular geometries' tutorial##################
# imports and relevant defines:
import pennylane as qml
from pennylane import qchem
from pennylane import numpy as np
import time

# Simulation starting parameters:
symbols = ["O", "H", "H"]

# this is selected from the tutorial 'Building molecular Hamiltonians', which has the same nulcear-coordinats for water
x = np.array([ 0.        ,  0.7581    , -0.5086    , -1.49139892,  0.29819887,
        -1.2393812 , -0.68850404,  2.16155953,  0.21671681], requires_grad=True)

# these parameters are used to match up with the parameters for the VQE run on water in the paper: https://arxiv.org/pdf/2106.13840.pdf
active_electrons = 8
active_orbitals = 6

# define the hamiltonian needed to compute cost-function
def H(x):
    return qchem.molecular_hamiltonian(
        symbols,
        x,
        charge = 0,
        mult=1,
        active_electrons = active_electrons,
        active_orbitals = active_orbitals)[0]



################ Code from the 'Building the adaptive circuit' tutorial below:################

geometry = np.array([ 0.        ,  0.7581    , -0.5086    , -1.49139892,  0.29819887,
        -1.2393812 , -0.68850404,  2.16155953,  0.21671681], requires_grad=True)
active_electrons = 8
active_orbitals = 6 

H, qubits = qchem.molecular_hamiltonian(symbols, geometry, charge = 0, mult=1, active_electrons=active_electrons, active_orbitals=active_orbitals)
singles, doubles = qchem.excitations(active_electrons, qubits)

hf_state = qchem.hf_state(active_electrons, qubits)



#compute the significant double-excitation gates:
def circuit_1(params, excitations):
    qml.BasisState(hf_state, wires=range(qubits))

    for i, excitation in enumerate(excitations):
        if len(excitation) == 4:
            qml.DoubleExcitation(params[i], wires=excitation)
        else:
            qml.SingleExcitation(params[i], wires=excitation)
    return qml.expval(H)

dev = qml.device("default.qubit", wires=qubits)
cost_fn = qml.QNode(circuit_1, dev, interface="autograd")
circuit_gradient = qml.grad(cost_fn, argnum=0)
params = [0.0] * len(doubles)
grads = circuit_gradient(params, excitations=doubles)
print("Computed gradients for all possible Double Excitation Gates: \n")
for i in range(len(doubles)):
    print(f"Excitation : {doubles[i]}, Gradient: {grads[i]}")   
doubles_select = [doubles[i] for i in range(len(doubles)) if abs(grads[i]) > 1.0e-5]
print("")
print("Number of selected double-excitation gates: ", len(doubles_select))



# optimizing the parameters for the double-excitation gates for Ansatz-wavefunction construction
opt = qml.GradientDescentOptimizer(stepsize=0.5)
params_doubles = np.zeros(len(doubles_select), requires_grad=True)
for n in range(20):
    params_doubles = opt.step(cost_fn, params_doubles, excitations=doubles_select)
print("Done!")



#compute the significant single-excitation gates:
def circuit_2(params, excitations, gates_select, params_select):
    qml.BasisState(hf_state, wires=range(qubits))

    for i, gate in enumerate(gates_select):
        if len(gate) == 4:
            qml.DoubleExcitation(params_select[i], wires=gate)
        elif len(gate) == 2:
            qml.SingleExcitation(params_select[i], wires=gate)

    for i, gate in enumerate(excitations):
        if len(gate) == 4:
            qml.DoubleExcitation(params[i], wires=gate)
        elif len(gate) == 2:
            qml.SingleExcitation(params[i], wires=gate)
    return qml.expval(H)


cost_fn = qml.QNode(circuit_2, dev, interface="autograd")
circuit_gradient = qml.grad(cost_fn, argnum=0)
params = [0.0] * len(singles)
grads = circuit_gradient(
    params,
    excitations=singles,
    gates_select=doubles_select,
    params_select=params_doubles
)
print("Computed gradients for all possible Single Excitation Gates: \n")
for i in range(len(singles)):
    print(f"Excitation : {singles[i]}, Gradient: {grads[i]}")
singles_select = [singles[i] for i in range(len(singles)) if abs(grads[i]) > 1.0e-5]
print("")
print("Number of selected single-excitation gates: ", len(singles_select))

#Total Number of Gates selected to construct the Quantum Ansatz:
print("Total selected gates: "+  str(len(doubles_select) + len(singles_select)))

################# End code from the 'Building the adaptive circuit' tutorial ##################

################ Resume from the 'Optimization of molecular geometries' tutorial below: ################
hf = hf_state


#Construct optimized parametrized circuit that will be used to run the optimized VQE algorithm
# using the selected single and double excitation gates:
num_wires = qubits
dev = qml.device("lightning.qubit", wires=num_wires)
@qml.qnode(dev, interface="autograd")
def circuit(params, obs, wires):
    # prepares reference state
    qml.BasisState(hf, wires=wires)
    
    # apply all single excitations
    for i, singles in enumerate(singles_select):
        qml.SingleExcitation(params[i], wires=singles)
        
    # apply all double excitations
    for j, doubles in enumerate(doubles_select):
        qml.DoubleExcitation(params[j + len(singles_select)], wires=doubles)
                             
    # returns expectation value of the ansatz prepared from this quantum circuit:   
    return qml.expval(obs)

def cost(params, x):
    hamiltonian = H(x)
    return circuit(params, obs=hamiltonian, wires=range(num_wires)) 
    

# This function computes the finite-difference of the Hamiltonian itself with respect to each of the nuclear-coordinates
# itself, using a central-difference approximation.
def finite_diff(f, x, delta=0.01):
    """Compute the central-difference finite difference of a function"""
    gradient = []
    for i in range(len(x)):
        shift = np.zeros_like(x)
        shift[i] += 0.5 * delta
        res = (f(x + shift) - f(x - shift)) * delta**-1 # dH/dx            
        gradient.append(res)

    return gradient

def grad_x(params, x): #evaluate the expectation of the gradient components (each of the nuclear components of the Hamiltonian)
    grad_h = finite_diff(H, x)
    grad = [circuit(params, obs=obs, wires=range(num_wires)) for obs in grad_h]
    return np.array(grad)



# initialize optimizers:
opt_theta = qml.GradientDescentOptimizer(stepsize=0.2)
opt_x = qml.AdamOptimizer(stepsize=0.01)


# functions to keep track of convergence of O-H1 and O-H2 bond angle during water's geometry optimization
import math
def unit_vector(vector):
    """ Returns the unit vector of the vector.  """
    return vector / np.linalg.norm(vector)

def angle_between(v1, v2):
    """ Returns the angle in radians between vectors 'v1' and 'v2'::

            >>> angle_between((1, 0, 0), (0, 1, 0))
            1.5707963267948966
            >>> angle_between((1, 0, 0), (1, 0, 0))
            0.0
            >>> angle_between((1, 0, 0), (-1, 0, 0))
            3.141592653589793
    """
    v1_u = unit_vector(v1)
    v2_u = unit_vector(v2)
    return (np.arccos(np.clip(np.dot(v1_u, v2_u), -1.0, 1.0)) * 180/math.pi) #convert to degrees


# Re-initialize all relevant parameters to be optimized:
# nuclear-coordinate parameters:
symbols = ["O", "H", "H"]
x = np.array([ 0.        ,  0.7581    , -0.5086    , -1.49139892,  0.29819887,
        -1.2393812 , -0.68850404,  2.16155953,  0.21671681], requires_grad=True)

# circuit parameters:
theta = np.array([0.0] * (len(doubles_select) + len(singles_select)), requires_grad=True)

print("Reinitialized gradient descent parameters!")




# re-define the hamiltonian needed to compute cost-function (otherwise it gives error: Hamiltonian function not callable
# when I run the actual gradient descent code below)
def H(x):
    return qchem.molecular_hamiltonian(
        symbols,
        x,
        charge = 0,
        mult=1,
        active_electrons = active_electrons,
        active_orbitals = active_orbitals)[0]




# ~~~~~~~~~~~~~~ Final block: Calculating water's molecular geometry ~~~~~~~~~~~~~~~
from functools import partial

# store the values of the cost function
energy = []

# store the values of the first OH-bond length
bond_length = []

#store the value of the bond_angle:
bond_angle = []

# Factor to convert from Bohrs to Angstroms
bohr_angs = 0.529177210903


# Calculate starting water-molecule parameters:
OH1 = x[0:3] - x[3:6]
OH2 = x[0:3] - x[6:9]
print("Starting bond length: " + str(np.linalg.norm(x[0:3] - x[3:6]) * bohr_angs) + " Å")
print("Starting bond angle: " + str(angle_between(OH1, OH2)) + '\u00b0')
print("")

'''
Errors (and how to fix):

If error 'Hamiltonian object is not callable', re-run cell that defines H(x) all the way at the top.
If the starting bond length and angle are off, re-run cell that defines symbols and geometry for x all the way at the top
'''

eps = 1e-05
n = 0

start = time.time()
while True:

    print("Starting step " + str(n) + ":")
    print("Calculating circuit parameters gradient")
    # Optimize the circuit parameters
    theta.requires_grad = True
    x.requires_grad = False
    theta, _ = opt_theta.step(cost, theta, x) # compare with final block of code in 'Adapt-VQE' tutorial on Pennylane

    print("Calculating nuclear coordinates parameters gradient")
    # Optimize the nuclear coordinates
    theta.requires_grad = False
    x.requires_grad = True
    _, x = opt_x.step(cost, theta, x, grad_fn=grad_x)
    print("Finished calculating nuclear coordinates parameters gradient")
    

    energy.append(cost(theta, x))
    bond_length.append(np.linalg.norm(x[0:3] - x[3:6]) * bohr_angs)
    
    #calculate bond-angle between both OH-bonds
    OH1 = x[0:3] - x[3:6]
    OH2 = x[0:3] - x[6:9]
    bond_angle.append(angle_between(OH1, OH2))

    if n % 1 == 0:
        print(f"Step = {n},  E = {energy[-1]:.8f} Ha,  bond length = {bond_length[-1]:.5f} Å, bond angle = {bond_angle[-1]:.5f}" + '\u00b0')

    n += 1
    # Check maximum component of the nuclear gradient:
    max_grad = np.max(grad_x(theta, x))
    print("Max grad:", max_grad)
    print("")
    
    if n <= 1:
        continue
    
    if max_grad <= 1e-05 or np.abs(energy[-2]-energy[-1]) < eps:
        break
        

print("Total time:", time.time()-start, "seconds")

print("\n" f"Final value of the ground-state energy = {energy[-1]:.8f} Ha")
print("\n" "Ground-state equilibrium geometry")
print("%s %4s %8s %8s" % ("symbol", "x", "y", "z"))
for i, atom in enumerate(symbols):
    print(f"  {atom}    {x[3 * i]:.4f}   {x[3 * i + 1]:.4f}   {x[3 * i + 2]:.4f}")
# Out:
# Computed gradients for all possible Double Excitation Gates:
#
# Excitation : [0, 1, 8, 9], Gradient: -0.10631894572187418
# Excitation : [0, 1, 8, 11], Gradient: 0.0
# Excitation : [0, 1, 9, 10], Gradient: 0.0
# Excitation : [0, 1, 10, 11], Gradient: -0.059240875717551184
# Excitation : [0, 2, 8, 10], Gradient: -0.039875832213294854
# Excitation : [0, 3, 8, 9], Gradient: 0.0
# Excitation : [0, 3, 8, 11], Gradient: 0.0772097850362808
# Excitation : [0, 3, 9, 10], Gradient: -0.03733395282298593
# Excitation : [0, 3, 10, 11], Gradient: 0.0
# Excitation : [0, 4, 8, 10], Gradient: 0.0
# Excitation : [0, 5, 8, 9], Gradient: 0.05732746246971731
# Excitation : [0, 5, 8, 11], Gradient: 0.0
# Excitation : [0, 5, 9, 10], Gradient: 0.0
# Excitation : [0, 5, 10, 11], Gradient: -0.014036506114198311
# Excitation : [0, 6, 8, 10], Gradient: 0.0
# Excitation : [0, 7, 8, 9], Gradient: 0.0
# Excitation : [0, 7, 8, 11], Gradient: 0.0
# Excitation : [0, 7, 9, 10], Gradient: 0.0
# Excitation : [0, 7, 10, 11], Gradient: 0.0
# Excitation : [1, 2, 8, 9], Gradient: 0.0
# Excitation : [1, 2, 8, 11], Gradient: -0.03733395282298593
# Excitation : [1, 2, 9, 10], Gradient: 0.0772097850362808
# Excitation : [1, 2, 10, 11], Gradient: 0.0
# Excitation : [1, 3, 9, 11], Gradient: -0.039875832213294854
# Excitation : [1, 4, 8, 9], Gradient: -0.05732746246971731
# Excitation : [1, 4, 8, 11], Gradient: 0.0
# Excitation : [1, 4, 9, 10], Gradient: 0.0
# Excitation : [1, 4, 10, 11], Gradient: 0.014036506114198311
# Excitation : [1, 5, 9, 11], Gradient: 0.0
# Excitation : [1, 6, 8, 9], Gradient: 0.0
# Excitation : [1, 6, 8, 11], Gradient: 0.0
# Excitation : [1, 6, 9, 10], Gradient: 0.0
# Excitation : [1, 6, 10, 11], Gradient: 0.0
# Excitation : [1, 7, 9, 11], Gradient: 0.0
# Excitation : [2, 3, 8, 9], Gradient: -0.06122875839768579
# Excitation : [2, 3, 8, 11], Gradient: 0.0
# Excitation : [2, 3, 9, 10], Gradient: 0.0
# Excitation : [2, 3, 10, 11], Gradient: -0.15400361863678078
# Excitation : [2, 4, 8, 10], Gradient: -0.03955460906339513
# Excitation : [2, 5, 8, 9], Gradient: 0.0
# Excitation : [2, 5, 8, 11], Gradient: -0.03899594659188468
# Excitation : [2, 5, 9, 10], Gradient: 0.07855055565527978
# Excitation : [2, 5, 10, 11], Gradient: 0.0
# Excitation : [2, 6, 8, 10], Gradient: 0.0
# Excitation : [2, 7, 8, 9], Gradient: 0.0
# Excitation : [2, 7, 8, 11], Gradient: 0.0
# Excitation : [2, 7, 9, 10], Gradient: 0.0
# Excitation : [2, 7, 10, 11], Gradient: 0.0
# Excitation : [3, 4, 8, 9], Gradient: 0.0
# Excitation : [3, 4, 8, 11], Gradient: 0.07855055565527978
# Excitation : [3, 4, 9, 10], Gradient: -0.03899594659188468
# Excitation : [3, 4, 10, 11], Gradient: 0.0
# Excitation : [3, 5, 9, 11], Gradient: -0.03955460906339513
# Excitation : [3, 6, 8, 9], Gradient: 0.0
# Excitation : [3, 6, 8, 11], Gradient: 0.0
# Excitation : [3, 6, 9, 10], Gradient: 0.0
# Excitation : [3, 6, 10, 11], Gradient: 0.0
# Excitation : [3, 7, 9, 11], Gradient: 0.0
# Excitation : [4, 5, 8, 9], Gradient: -0.06877433885498158
# Excitation : [4, 5, 8, 11], Gradient: 0.0
# Excitation : [4, 5, 9, 10], Gradient: 0.0
# Excitation : [4, 5, 10, 11], Gradient: -0.07270045526613919
# Excitation : [4, 6, 8, 10], Gradient: 0.0
# Excitation : [4, 7, 8, 9], Gradient: 0.0
# Excitation : [4, 7, 8, 11], Gradient: 0.0
# Excitation : [4, 7, 9, 10], Gradient: 0.0
# Excitation : [4, 7, 10, 11], Gradient: 0.0
# Excitation : [5, 6, 8, 9], Gradient: 0.0
# Excitation : [5, 6, 8, 11], Gradient: 0.0
# Excitation : [5, 6, 9, 10], Gradient: 0.0
# Excitation : [5, 6, 10, 11], Gradient: 0.0
# Excitation : [5, 7, 9, 11], Gradient: 0.0
# Excitation : [6, 7, 8, 9], Gradient: -0.03945498806698956
# Excitation : [6, 7, 8, 11], Gradient: 0.0
# Excitation : [6, 7, 9, 10], Gradient: 0.0
# Excitation : [6, 7, 10, 11], Gradient: -0.02305810549283035
#
# Number of selected double-excitation gates:  24
# Done!
# Computed gradients for all possible Single Excitation Gates:
#
# Excitation : [0, 8], Gradient: -0.00034050286717786696
# Excitation : [0, 10], Gradient: 0.0
# Excitation : [1, 9], Gradient: -0.00037582961304511906
# Excitation : [1, 11], Gradient: 0.0
# Excitation : [2, 8], Gradient: 0.0
# Excitation : [2, 10], Gradient: -0.005247740262885408
# Excitation : [3, 9], Gradient: 0.0
# Excitation : [3, 11], Gradient: 0.005281086319074415
# Excitation : [4, 8], Gradient: -0.007389627371019285
# Excitation : [4, 10], Gradient: 0.0
# Excitation : [5, 9], Gradient: 0.007422730922514338
# Excitation : [5, 11], Gradient: 0.0
# Excitation : [6, 8], Gradient: 0.0
# Excitation : [6, 10], Gradient: 0.0
# Excitation : [7, 9], Gradient: 0.0
# Excitation : [7, 11], Gradient: 0.0
#
# Number of selected single-excitation gates:  6
# Total selected gates: 30
# Reinitialized gradient descent parameters!
# Starting bond length: 0.9119400018409726 Å
# Starting bond angle: 92.86936991180738°
#
# Starting step 0:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 0,  E = -74.95169281 Ha,  bond length = 0.89550 Å, bond angle = 92.76834°
# Max grad: 0.12045828747941444
#
# Starting step 1:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 1,  E = -74.96281416 Ha,  bond length = 0.88590 Å, bond angle = 92.64294°
# Max grad: 0.1573659462032602
#
# Starting step 2:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 2,  E = -74.96842986 Ha,  bond length = 0.87997 Å, bond angle = 92.50180°
# Max grad: 0.1839616840321548
#
# Starting step 3:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 3,  E = -74.97145646 Ha,  bond length = 0.87661 Å, bond angle = 92.35076°
# Max grad: 0.20100586772036394
#
# Starting step 4:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 4,  E = -74.97342251 Ha,  bond length = 0.87522 Å, bond angle = 92.19435°
# Max grad: 0.21092565328230287
#
# Starting step 5:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 5,  E = -74.97507469 Ha,  bond length = 0.87542 Å, bond angle = 92.03610°
# Max grad: 0.2156567868933705
#
# Starting step 6:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 6,  E = -74.97675457 Ha,  bond length = 0.87693 Å, bond angle = 91.87875°
# Max grad: 0.2165910363363398
#
# Starting step 7:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 7,  E = -74.97859952 Ha,  bond length = 0.87952 Å, bond angle = 91.72439°
# Max grad: 0.21474796617492342
#
# Starting step 8:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 8,  E = -74.98064668 Ha,  bond length = 0.88303 Å, bond angle = 91.57458°
# Max grad: 0.21090226367708273
#
# Starting step 9:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 9,  E = -74.98288666 Ha,  bond length = 0.88731 Å, bond angle = 91.43045°
# Max grad: 0.20565892773076896
#
# Starting step 10:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 10,  E = -74.98529126 Ha,  bond length = 0.89225 Å, bond angle = 91.29285°
# Max grad: 0.19949451258176143
#
# Starting step 11:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 11,  E = -74.98782754 Ha,  bond length = 0.89773 Å, bond angle = 91.16237°
# Max grad: 0.19277642481166032
#
# Starting step 12:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 12,  E = -74.99046452 Ha,  bond length = 0.90369 Å, bond angle = 91.03941°
# Max grad: 0.18576521721702516
#
# Starting step 13:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 13,  E = -74.99317549 Ha,  bond length = 0.91003 Å, bond angle = 90.92424°
# Max grad: 0.17860000567404694
#
# Starting step 14:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 14,  E = -74.95544320 Ha,  bond length = 0.91670 Å, bond angle = 90.81695°
# Max grad: 4.116210985659221
#
# Starting step 15:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 15,  E = -74.99392223 Ha,  bond length = 0.91628 Å, bond angle = 91.19309°
# Max grad: 0.1570644236621109
#
# Starting step 16:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 16,  E = -74.99540861 Ha,  bond length = 0.91629 Å, bond angle = 91.53207°
# Max grad: 0.16053656539954292
#
# Starting step 17:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 17,  E = -74.99661399 Ha,  bond length = 0.91670 Å, bond angle = 91.83608°
# Max grad: 0.16122312516738452
#
# Starting step 18:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 18,  E = -74.99760570 Ha,  bond length = 0.91747 Å, bond angle = 92.10709°
# Max grad: 0.1589477364019177
#
# Starting step 19:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 19,  E = -74.99841674 Ha,  bond length = 0.91857 Å, bond angle = 92.34698°
# Max grad: 0.1537030633885519
#
# Starting step 20:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 20,  E = -74.99906165 Ha,  bond length = 0.91995 Å, bond angle = 92.55752°
# Max grad: 0.14569559294763185
#
# Starting step 21:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 21,  E = -74.99954877 Ha,  bond length = 0.92158 Å, bond angle = 92.74040°
# Max grad: 0.13535643675213696
#
# Starting step 22:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 22,  E = -74.99988897 Ha,  bond length = 0.92340 Å, bond angle = 92.89734°
# Max grad: 0.12330425320049444
#
# Starting step 23:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 23,  E = -74.94879347 Ha,  bond length = 0.92537 Å, bond angle = 93.03002°
# Max grad: 5.162983143622124
#
# Starting step 24:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 24,  E = -74.99630077 Ha,  bond length = 0.92008 Å, bond angle = 93.07640°
# Max grad: 0.12570820387959794
#
# Starting step 25:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 25,  E = -74.99627495 Ha,  bond length = 0.91546 Å, bond angle = 93.11071°
# Max grad: 0.14780464381626315
#
# Starting step 26:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 26,  E = -74.99573125 Ha,  bond length = 0.91149 Å, bond angle = 93.13418°
# Max grad: 0.16601038202159282
#
# Starting step 27:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 27,  E = -74.99493742 Ha,  bond length = 0.90814 Å, bond angle = 93.14798°
# Max grad: 0.1802294288437721
#
# Starting step 28:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 28,  E = -74.99408111 Ha,  bond length = 0.90539 Å, bond angle = 93.15321°
# Max grad: 0.19087813446193938
#
# Starting step 29:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 29,  E = -74.99328375 Ha,  bond length = 0.90320 Å, bond angle = 93.15087°
# Max grad: 0.1985509217636057
#
# Starting step 30:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 30,  E = -74.99261724 Ha,  bond length = 0.90154 Å, bond angle = 93.14186°
# Max grad: 0.20383516136868035
#
# Starting step 31:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 31,  E = -74.99211927 Ha,  bond length = 0.90039 Å, bond angle = 93.12696°
# Max grad: 0.20723488780045085
#
# Starting step 32:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 32,  E = -74.99180520 Ha,  bond length = 0.89969 Å, bond angle = 93.10687°
# Max grad: 0.20915411079351445
#
# Starting step 33:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 33,  E = -74.99167658 Ha,  bond length = 0.89943 Å, bond angle = 93.08220°
# Max grad: 0.20990595327622658
#
# Starting step 34:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 34,  E = -74.99172680 Ha,  bond length = 0.89957 Å, bond angle = 93.05349°
# Max grad: 0.20972953822753834
#
# Starting step 35:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 35,  E = -74.99194473 Ha,  bond length = 0.90008 Å, bond angle = 93.02123°
# Max grad: 0.2088066032857343
#
# Starting step 36:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 36,  E = -74.99231693 Ha,  bond length = 0.90093 Å, bond angle = 92.98583°
# Max grad: 0.20727505018161854
#
# Starting step 37:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 37,  E = -74.99282905 Ha,  bond length = 0.90209 Å, bond angle = 92.94769°
# Max grad: 0.2052389841660014
#
# Starting step 38:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 38,  E = -74.99346656 Ha,  bond length = 0.90354 Å, bond angle = 92.90715°
# Max grad: 0.20277566719993845
#
# Starting step 39:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 39,  E = -74.99421520 Ha,  bond length = 0.90525 Å, bond angle = 92.86453°
# Max grad: 0.19994004032031526
#
# Starting step 40:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 40,  E = -74.99506111 Ha,  bond length = 0.90719 Å, bond angle = 92.82011°
# Max grad: 0.19676744717962724
#
# Starting step 41:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 41,  E = -74.99599093 Ha,  bond length = 0.90935 Å, bond angle = 92.77414°
# Max grad: 0.19327511016318588
#
# Starting step 42:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 42,  E = -74.99699169 Ha,  bond length = 0.91171 Å, bond angle = 92.72684°
# Max grad: 0.18946283881422427
#
# Starting step 43:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 43,  E = -74.99805072 Ha,  bond length = 0.91424 Å, bond angle = 92.67843°
# Max grad: 0.18531342479730684
#
# Starting step 44:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 44,  E = -74.99915543 Ha,  bond length = 0.91692 Å, bond angle = 92.62906°
# Max grad: 0.18079318915329878
#
# Starting step 45:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 45,  E = -75.00029314 Ha,  bond length = 0.91973 Å, bond angle = 92.57891°
# Max grad: 0.1758531985330784
#
# Starting step 46:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 46,  E = -75.00145088 Ha,  bond length = 0.92267 Å, bond angle = 92.52808°
# Max grad: 0.17043171602984675
#
# Starting step 47:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 47,  E = -75.00261527 Ha,  bond length = 0.92570 Å, bond angle = 92.47670°
# Max grad: 0.16445846752246618
#
# Starting step 48:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 48,  E = -75.00377241 Ha,  bond length = 0.92882 Å, bond angle = 92.42485°
# Max grad: 0.15786121047835447
#
# Starting step 49:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 49,  E = -75.00490801 Ha,  bond length = 0.93200 Å, bond angle = 92.37259°
# Max grad: 0.15057481571131984
#
# Starting step 50:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 50,  E = -75.00600767 Ha,  bond length = 0.93523 Å, bond angle = 92.32000°
# Max grad: 0.1425525591991167
#
# Starting step 51:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 51,  E = -75.00705731 Ha,  bond length = 0.93848 Å, bond angle = 92.26713°
# Max grad: 0.13377857711779947
#
# Starting step 52:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 52,  E = -75.00804391 Ha,  bond length = 0.94175 Å, bond angle = 92.21404°
# Max grad: 0.12427960313608846
#
# Starting step 53:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 53,  E = -75.00895638 Ha,  bond length = 0.94500 Å, bond angle = 92.16078°
# Max grad: 5.955997131052374
#
# Starting step 54:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 54,  E = -75.00907398 Ha,  bond length = 0.94503 Å, bond angle = 92.40040°
# Max grad: 0.11095724489723324
#
# Starting step 55:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 55,  E = -75.00920670 Ha,  bond length = 0.94528 Å, bond angle = 92.61790°
# Max grad: 0.10719228367105965
#
# Starting step 56:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 56,  E = -75.00935428 Ha,  bond length = 0.94571 Å, bond angle = 92.81480°
# Max grad: 0.10296925305190824
#
# Starting step 57:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 57,  E = -75.00951557 Ha,  bond length = 0.94630 Å, bond angle = 92.99250°
# Max grad: 0.0984125351696645
#
# Starting step 58:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 58,  E = -75.00968924 Ha,  bond length = 0.94702 Å, bond angle = 93.15236°
# Max grad: 6.300244321661946
#
# Starting step 59:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 59,  E = -75.00989944 Ha,  bond length = 0.94693 Å, bond angle = 93.18210°
# Max grad: 0.0990090575781197
#
# Starting step 60:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 60,  E = -75.01011235 Ha,  bond length = 0.94704 Å, bond angle = 93.20619°
# Max grad: 0.10323572419886973
#
# Starting step 61:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 61,  E = -75.01033756 Ha,  bond length = 0.94736 Å, bond angle = 93.22540°
# Max grad: 0.10637448684742837
#
# Starting step 62:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 62,  E = -75.01058187 Ha,  bond length = 0.94786 Å, bond angle = 93.24040°
# Max grad: 0.1084977475946302
#
# Starting step 63:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 63,  E = -75.01084949 Ha,  bond length = 0.94854 Å, bond angle = 93.25180°
# Max grad: 0.10968552091914646
#
# Starting step 64:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 64,  E = -75.01114233 Ha,  bond length = 0.94938 Å, bond angle = 93.26011°
# Max grad: 0.11001860789282952
#
# Starting step 65:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 65,  E = -75.01146035 Ha,  bond length = 0.95038 Å, bond angle = 93.26575°
# Max grad: 6.356070138329201
#
# Starting step 66:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 66,  E = -75.01131255 Ha,  bond length = 0.94933 Å, bond angle = 93.46953°
# Max grad: 0.11335477432912816
#
# Starting step 67:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 67,  E = -75.01122857 Ha,  bond length = 0.94861 Å, bond angle = 93.65406°
# Max grad: 0.11588984553019542
#
# Starting step 68:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 68,  E = -75.01121008 Ha,  bond length = 0.94819 Å, bond angle = 93.82104°
# Max grad: 0.11732532198312796
#
# Starting step 69:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 69,  E = -75.01125552 Ha,  bond length = 0.94805 Å, bond angle = 93.97202°
# Max grad: 0.11778968531244897
#
# Starting step 70:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 70,  E = -75.01136097 Ha,  bond length = 0.94816 Å, bond angle = 94.10840°
# Max grad: 0.11739447569184777
#
# Starting step 71:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 71,  E = -75.01152086 Ha,  bond length = 0.94851 Å, bond angle = 94.23143°
# Max grad: 0.11623612390666543
#
# Starting step 72:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 72,  E = -75.01172860 Ha,  bond length = 0.94908 Å, bond angle = 94.34228°
# Max grad: 0.11439853719320593
#
# Starting step 73:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 73,  E = -75.01197693 Ha,  bond length = 0.94983 Å, bond angle = 94.44198°
# Max grad: 0.11195596193596918
#
# Starting step 74:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 74,  E = -75.01225835 Ha,  bond length = 0.95076 Å, bond angle = 94.53148°
# Max grad: 0.10897581658732668
#
# Starting step 75:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 75,  E = -75.01256538 Ha,  bond length = 0.95183 Å, bond angle = 94.61163°
# Max grad: 0.10552129207530239
#
# Starting step 76:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 76,  E = -75.01289081 Ha,  bond length = 0.95304 Å, bond angle = 94.68322°
# Max grad: 0.10165357167321304
#
# Starting step 77:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 77,  E = -75.01322789 Ha,  bond length = 0.95435 Å, bond angle = 94.74696°
# Max grad: 0.09743356167907052
#
# Starting step 78:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 78,  E = -75.01357053 Ha,  bond length = 0.95576 Å, bond angle = 94.80350°
# Max grad: 0.09292305214030862
#
# Starting step 79:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 79,  E = -75.01391339 Ha,  bond length = 0.95725 Å, bond angle = 94.85345°
# Max grad: 0.08818526642778943
#
# Starting step 80:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 80,  E = -75.01425203 Ha,  bond length = 0.95879 Å, bond angle = 94.89735°
# Max grad: 0.08328480050030193
#
# Starting step 81:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 81,  E = -75.01458291 Ha,  bond length = 0.96038 Å, bond angle = 94.93571°
# Max grad: 0.07828700741226319
#
# Starting step 82:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 82,  E = -75.01490342 Ha,  bond length = 0.96200 Å, bond angle = 94.96901°
# Max grad: 6.703794006158411
#
# Starting step 83:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 83,  E = -75.01384502 Ha,  bond length = 0.95522 Å, bond angle = 95.24983°
# Max grad: 0.10865983047822232
#
# Starting step 84:
# Calculating circuit parameters gradient
# Calculating nuclear coordinates parameters gradient
# Finished calculating nuclear coordinates parameters gradient
# Step = 84,  E = -75.01214670 Ha,  bond length = 0.94923 Å, bond angle = 95.50279°
# KeyboardInterrupt
